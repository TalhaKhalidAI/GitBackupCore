# %%
# from App.core.git_core import GitCore
import sys
import os

# %%
sys.path.insert(0, os.path.abspath(".."))

# %%
sys.path
# Out:
# ['/home/talha/Documents/DEv/Python/Learn/dwt/MyAPi',
#  '/home/talha/Documents/DEv/Python/Learn/dwt/MyAPi/tests/...',
#  '/home/talha/Documents/DEv/Python/Learn/dwt/MyAPi/tests',
#  '/home/talha/Documents/DEv/Python/Learn/dwt/MyAPi',
#  '/home/talha/anaconda3/envs/fastapi/lib/python310.zip',
#  '/home/talha/anaconda3/envs/fastapi/lib/python3.10',
#  '/home/talha/anaconda3/envs/fastapi/lib/python3.10/lib-dynload',
#  '',
#  '/home/talha/anaconda3/envs/fastapi/lib/python3.10/site-packages']

# %%
gt=GitCore()

# %%
test=gt.init_git("talha","main")

# %%
test
# Out:
# <coroutine object GitCore.init_git at 0x76e6ef41d000>
